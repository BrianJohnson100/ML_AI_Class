# %% [markdown]
# ### Assignment: What factors contribute to a customer accepting the coupon?
#
# *Context My objective is to understand the factors that influence a drivers decision to accept a location-based
# mobile coupon while driving. I aim to explore how variables such as the type of business
# (e.g., restaurant, bar, coffee house), the presence of passengers (including minors),
# proximity to the business, weather conditions, and time of day affect coupon acceptance behavior.
# By analyzing these factorsL, I intend to develop a predictive model or framework that can determine the
# likelihood of a driver accepting a coupon once it is delivered to them.*
#
#
# *My goal in this project is to apply my understanding of visualizations and probability distributions
# to effectively distinguish between customers who accepted a driving coupon and those who did not. By
# analyzing patterns in the data, I aim to uncover meaningful insights that can help predict coupon
# acceptance behavior.*

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px

# %%
df = pd.read_csv('data/coupons.csv')

# %%
df.head(5)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# 1        never       NaN                  4~8              1~3
# 2        never       NaN                  4~8              1~3
# 3        never       NaN                  4~8              1~3
# 4        never       NaN                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                1                 0                 0              0
# 1                1                 0                 0              0
# 2                1                 1                 0              0
# 3                1                 1                 0              0
# 4                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
# 3             1  0
# 4             1  0
#
# [5 rows x 26 columns]

# %% [markdown]
# **DateFrame Review:**
#
# 1. info()
# 2. describe()
# 3. shape
# 4. columns
# 5. head()
# 6. nunique()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
#  15  Bar                   12577 non-null  object
#  16  CoffeeHouse           12467 non-null  object
#  17  CarryAway             12533 non-null  object
#  18  RestaurantLessThan20  12554 non-null  object
#  19  Restaurant20To50      12495 non-null  object
#  20  toCoupon_GEQ5min      12684 non-null  int64
#  21  toCoupon_GEQ15min     12684 non-null  int64
#  22  toCoupon_GEQ25min     12684 non-null  int64
#  23  direction_same        12684 non-null  int64
#  24  direction_opp         12684 non-null  int64
#  25  Y                     12684 non-null  int64
# dtypes: int64(8), object(18)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# min             0.000000        0.000000       0.000000      0.000000
# 25%             0.000000        0.000000       1.000000      0.000000
# 50%             0.000000        0.000000       1.000000      1.000000
# 75%             0.000000        0.000000       1.000000      1.000000
# max             1.000000        1.000000       1.000000      1.000000

# %%
df.shape
# Out:
# (12684, 26)

# %%
df.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'car', 'Bar', 'CoffeeHouse',
#        'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50',
#        'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp', 'Y'],
#       dtype='object')

# %%
df.head(3)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# 1        never       NaN                  4~8              1~3
# 2        never       NaN                  4~8              1~3
#
#   toCoupon_GEQ5min toCoupon_GEQ15min toCoupon_GEQ25min direction_same  \
# 0                1                 0                 0              0
# 1                1                 0                 0              0
# 2                1                 1                 0              0
#
#   direction_opp  Y
# 0             1  1
# 1             1  0
# 2             1  1
#
# [3 rows x 26 columns]

# %%
df.nunique()
# Out:
# destination              3
# passanger                4
# weather                  3
# temperature              3
# time                     5
# coupon                   5
# expiration               2
# gender                   2
# age                      8
# maritalStatus            5
# has_children             2
# education                6
# occupation              25
# income                   9
# car                      5
# Bar                      5
# CoffeeHouse              5
# CarryAway                5
# RestaurantLessThan20     5
# Restaurant20To50         5
# toCoupon_GEQ5min         1
# toCoupon_GEQ15min        2
# toCoupon_GEQ25min        2
# direction_same           2
# direction_opp            2
# Y                        2
# dtype: int64

# %%
df.iloc[0:3,10:17]
# Out:
#    has_children                 education  occupation           income  car  \
# 0             1  Some college - no degree  Unemployed  $37500 - $49999  NaN
# 1             1  Some college - no degree  Unemployed  $37500 - $49999  NaN
# 2             1  Some college - no degree  Unemployed  $37500 - $49999  NaN
#
#      Bar CoffeeHouse
# 0  never       never
# 1  never       never
# 2  never       never

# %%
df = df.rename(columns={'destination':'Destination',
                       'passanger':'Passenger',
                       'weather':'Weather',
                       'temperature':'Temperature',
                       'time':'Time',
                       'coupon':'Coupon_Type',
                       'expiration':'Expiration_Date',
                       'gender':'Gender',
                       'age':'Age',
                       'maritalStatus':'Marital_Status',
                       'has_children':'Has_Children',
                       'education':'Education_Level',
                       'occupation':'Occupation_Type',
                       'income':'Income',
                       'car':'Car',
                       'Bar':'Bar_Frequency',
                        'toCoupon_GEQ5min':'Coupon_GEQ5min',
                        'toCoupon_GEQ15min':'Coupon_GEQ15min',
                        'toCoupon_GEQ25min':'Coupon_GEQ25min',
                        'direction_same':'Direction_Same',
                        'direction_opp':'Direction_opp',
                        'Y':'Coupon_Acceptance'})

# %%
df_sorted = df.sort_index(axis=1)

# %%
#Created by: Toby-Gardner-ai
#toby-gardner-ai

def summary_stats(df) -> pd.DataFrame:

    # Create base frame
    stats = pd.DataFrame(index=df.columns)

    stats["dtype"] = df.dtypes


    stats["sample_val"] = [df[col].dropna().sample(1).iloc[0]
                            if df[col].notna().any() else np.nan
                            for col in df.columns]

    stats["vals"] = df.count()
    stats["miss_pct"] = (df.isna().sum() / len(df) * 100).round(1)
    stats["unique"] = df.nunique()

    # Initiate Descriptive Stats
    for col in ["mean", "mode", "min", "max", "std", "skew", "kurtosis"]:
        stats[col] = np.nan

    # Compute stats for numeric columns
    num_cols = df.select_dtypes(include="number").columns

    for col in num_cols:
        s = df[col].dropna()
        if not s.empty:
            stats.at[col, "mean"] = s.mean()
            stats.at[col, "min"] = s.min()
            stats.at[col, "max"] = s.max()
            stats.at[col, "std"] = s.std()
            stats.at[col, "skew"] = s.skew().round(1)
            stats.at[col, "kurtosis"] = s.kurtosis().round(1)
            mode_vals = s.mode()
            stats.at[col, "mode"] = mode_vals.iloc[0] if not mode_vals.empty else np.nan

    # Rounding preferences for numeric stats (change this to suit dataset)
    round_cols = ["mean", "mode", "min", "max", "std"]
    stats[round_cols] = stats[round_cols].round(2)

    return stats

# %%
summary_stats(df)
# Out:
#                        dtype                sample_val   vals  miss_pct  \
# Destination           object           No Urgent Place  12684       0.0
# Passenger             object                     Alone  12684       0.0
# Weather               object                     Sunny  12684       0.0
# Temperature            int64                        55  12684       0.0
# Time                  object                      10PM  12684       0.0
# Coupon_Type           object                       Bar  12684       0.0
# Expiration_Date       object                        2h  12684       0.0
# Gender                object                      Male  12684       0.0
# Age                   object                        26  12684       0.0
# Marital_Status        object                    Single  12684       0.0
# Has_Children           int64                         1  12684       0.0
# Education_Level       object  Some college - no degree  12684       0.0
# Occupation_Type       object                     Legal  12684       0.0
# Income                object           $12500 - $24999  12684       0.0
# Car                   object                 crossover    108      99.1
# Bar_Frequency         object                     never  12577       0.8
# CoffeeHouse           object                     never  12467       1.7
# CarryAway             object                     less1  12533       1.2
# RestaurantLessThan20  object                       4~8  12554       1.0
# Restaurant20To50      object                     less1  12495       1.5
# Coupon_GEQ5min         int64                         1  12684       0.0
# Coupon_GEQ15min        int64                         1  12684       0.0
# Coupon_GEQ25min        int64                         0  12684       0.0
# Direction_Same         int64                         0  12684       0.0
# Direction_opp          int64                         1  12684       0.0
# Coupon_Acceptance      int64                         1  12684       0.0
#
#                       unique   mean  mode   min   max    std  skew  kurtosis
# Destination                3    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Passenger                  4    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Weather                    3    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Temperature                3  63.30  80.0  30.0  80.0  19.15  -0.6      -1.0
# Time                       5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Coupon_Type                5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Expiration_Date            2    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Gender                     2    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Age                        8    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Marital_Status             5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Has_Children               2   0.41   0.0   0.0   1.0   0.49   0.3      -1.9
# Education_Level            6    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Occupation_Type           25    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Income                     9    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Car                        5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Bar_Frequency              5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# CoffeeHouse                5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# CarryAway                  5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# RestaurantLessThan20       5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Restaurant20To50           5    NaN   NaN   NaN   NaN    NaN   NaN       NaN
# Coupon_GEQ5min             1   1.00   1.0   1.0   1.0   0.00   0.0       0.0
# Coupon_GEQ15min            2   0.56   1.0   0.0   1.0   0.50  -0.2      -1.9
# Coupon_GEQ25min            2   0.12   0.0   0.0   1.0   0.32   2.4       3.5
# Direction_Same             2   0.21   0.0   0.0   1.0   0.41   1.4      -0.1
# Direction_opp              2   0.79   1.0   0.0   1.0   0.41  -1.4      -0.1
# Coupon_Acceptance          2   0.57   1.0   0.0   1.0   0.50  -0.3      -1.9

# %%
# Example: df['time'] contains values like "7AM", "10AM", "2PM", "6PM"
df["time_24h"] = pd.to_datetime(df["Time"], format="%I%p").dt.strftime("%H:%M")
# e.g., "6PM" -> "18:00"

# %%
df[['Income lower bound','Income upper bound']] = df['Income'].str.split('-',expand=True)
df.drop('Income', axis=1)
# Out:
#            Destination  Passenger Weather  Temperature  Time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                  Coupon_Type Expiration_Date  Gender Age     Marital_Status  \
# 0            Restaurant(<20)              1d  Female  21  Unmarried partner
# 1               Coffee House              2h  Female  21  Unmarried partner
# 2      Carry out & Take away              2h  Female  21  Unmarried partner
# 3               Coffee House              2h  Female  21  Unmarried partner
# 4               Coffee House              1d  Female  21  Unmarried partner
# ...                      ...             ...     ...  ..                ...
# 12679  Carry out & Take away              1d    Male  26             Single
# 12680  Carry out & Take away              1d    Male  26             Single
# 12681           Coffee House              1d    Male  26             Single
# 12682                    Bar              1d    Male  26             Single
# 12683      Restaurant(20-50)              2h    Male  26             Single
#
#        ...  Restaurant20To50 Coupon_GEQ5min Coupon_GEQ15min Coupon_GEQ25min  \
# 0      ...               1~3              1               0               0
# 1      ...               1~3              1               0               0
# 2      ...               1~3              1               1               0
# 3      ...               1~3              1               1               0
# 4      ...               1~3              1               1               0
# ...    ...               ...            ...             ...             ...
# 12679  ...               1~3              1               0               0
# 12680  ...               1~3              1               0               0
# 12681  ...               1~3              1               0               0
# 12682  ...               1~3              1               1               1
# 12683  ...               1~3              1               0               0
#
#       Direction_Same Direction_opp Coupon_Acceptance time_24h  \
# 0                  0             1                 1    14:00
# 1                  0             1                 0    10:00
# 2                  0             1                 1    10:00
# 3                  0             1                 0    14:00
# 4                  0             1                 0    14:00
# ...              ...           ...               ...      ...
# 12679              1             0                 1    18:00
# 12680              0             1                 1    07:00
# 12681              1             0                 0    07:00
# 12682              0             1                 0    07:00
# 12683              1             0                 0    07:00
#
#       Income lower bound  Income upper bound
# 0                $37500               $49999
# 1                $37500               $49999
# 2                $37500               $49999
# 3                $37500               $49999
# 4                $37500               $49999
# ...                  ...                 ...
# 12679            $75000               $87499
# 12680            $75000               $87499
# 12681            $75000               $87499
# 12682            $75000               $87499
# 12683            $75000               $87499
#
# [12684 rows x 28 columns]

# %%
df.iloc[0:3,10:17]
# Out:
#    Has_Children           Education_Level Occupation_Type           Income  \
# 0             1  Some college - no degree      Unemployed  $37500 - $49999
# 1             1  Some college - no degree      Unemployed  $37500 - $49999
# 2             1  Some college - no degree      Unemployed  $37500 - $49999
#
#    Car Bar_Frequency CoffeeHouse
# 0  NaN         never       never
# 1  NaN         never       never
# 2  NaN         never       never

# %%
df['Income lower bound'] = df['Income lower bound'].str.replace('$', '', regex=False)

# %%
df['Income upper bound'] = df['Income upper bound'].str.replace('$', '', regex=False)

# %%
df.iloc[0:3,25:]
# Out:
#    Coupon_Acceptance time_24h Income lower bound Income upper bound
# 0                  1    14:00             37500               49999
# 1                  0    10:00             37500               49999
# 2                  1    10:00             37500               49999

# %%
df['Income lower bound'] = pd.to_numeric(df['Income lower bound'], errors='coerce').astype('Int64')

# %%
df['Income upper bound'] = pd.to_numeric(df['Income upper bound'], errors='coerce').astype('Int64')

# %% [markdown]
# 2. **Investigate the dataset for missing or problematic data.**

# %%
df.isnull().sum()
# Out:
# Destination                 0
# Passenger                   0
# Weather                     0
# Temperature                 0
# Time                        0
# Coupon_Type                 0
# Expiration_Date             0
# Gender                      0
# Age                         0
# Marital_Status              0
# Has_Children                0
# Education_Level             0
# Occupation_Type             0
# Income                      0
# Car                     12576
# Bar_Frequency             107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# Coupon_GEQ5min              0
# Coupon_GEQ15min             0
# Coupon_GEQ25min             0
# Direction_Same              0
# Direction_opp               0
# Coupon_Acceptance           0
# time_24h                    0
# Income lower bound       2778
# Income upper bound       2778
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Destination             0
# Passenger               0
# Weather                 0
# Temperature             0
# Time                    0
# Coupon_Type             0
# Expiration_Date         0
# Gender                  0
# Age                     0
# Marital_Status          0
# Has_Children            0
# Education_Level         0
# Occupation_Type         0
# Income                  0
# Car                     0
# Bar_Frequency           0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# Coupon_GEQ5min          0
# Coupon_GEQ15min         0
# Coupon_GEQ25min         0
# Direction_Same          0
# Direction_opp           0
# Coupon_Acceptance       0
# time_24h                0
# Income lower bound      0
# Income upper bound      0
# dtype: int64

# %% [markdown]
# **3. Decide what to do about your missing data -- drop, replace, other...**

# %%
df.drop_duplicates(inplace=True)

# %%
df=df.drop('Car',axis=1)

# %%
df = df[sorted(df.columns)]

# %%
df.columns
# Out:
# Index(['Age', 'Bar_Frequency', 'CarryAway', 'CoffeeHouse', 'Coupon_Acceptance',
#        'Coupon_GEQ15min', 'Coupon_GEQ25min', 'Coupon_GEQ5min', 'Coupon_Type',
#        'Destination', 'Direction_Same', 'Direction_opp', 'Education_Level',
#        'Expiration_Date', 'Gender', 'Has_Children', 'Income',
#        'Income lower bound', 'Income upper bound', 'Marital_Status',
#        'Occupation_Type', 'Passenger', 'Restaurant20To50',
#        'RestaurantLessThan20', 'Temperature', 'Time', 'Weather', 'time_24h'],
#       dtype='object')

# %%
#df_bygender = df.groupby(['gender')[['gender','coupon']].count()
grouped_df = df.groupby(['Coupon_Type','Occupation_Type', 'Gender'])['Occupation_Type'].count()
grouped_df
# Out:
# Coupon_Type      Occupation_Type                            Gender
# Bar              Architecture & Engineering                 Female      3
#                                                             Male       24
#                  Arts Design Entertainment Sports & Media   Female     83
#                                                             Male       17
#                  Building & Grounds Cleaning & Maintenance  Male        7
#                                                                      ...
# Restaurant(<20)  Student                                    Male      214
#                  Transportation & Material Moving           Female     13
#                                                             Male       33
#                  Unemployed                                 Female    276
#                                                             Male      135
# Name: Occupation_Type, Length: 240, dtype: int64

# %% [markdown]
# **4. What proportion of the total observations chose to accept the coupon?**

# %%
# The column 'Y' appears to represent whether the coupon was accepted (1 = Yes, 0 = No)
proportion_accepted = df['Coupon_Acceptance'].mean()
proportion_accepted = round(proportion_accepted * 100, 2)
print(f"Proportional amount of recipients who chose to accept the coupon: {proportion_accepted}%")
# Out:
# Proportional amount of recipients who chose to accept the coupon: 56.76%

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
coupon_counts = df['Coupon_Type'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='bar')

plt.title('Distribution of Coupon')
plt.xlabel('Coupon')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
# Create a histogram for the temperature column
plt.figure(figsize=(8, 5))
plt.hist(df['Temperature'], bins=10, edgecolor='black')#,orientation='horizontal')

plt.title('Distribution of Temperature')
plt.xlabel('Temperature (°F)')
plt.ylabel('count')
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons = df[df['Coupon_Type'] == 'Bar']
# Display the first few rows to confirm
bar_coupons.head(3)
# Out:
#    Age Bar_Frequency CarryAway CoffeeHouse  Coupon_Acceptance  \
# 9   21         never         0       never                  0
# 13  21         never         0       never                  1
# 17  21         never         0       never                  0
#
#     Coupon_GEQ15min  Coupon_GEQ25min  Coupon_GEQ5min Coupon_Type  \
# 9                 1                0               1         Bar
# 13                0                0               1         Bar
# 17                1                1               1         Bar
#
#         Destination  ...  Income upper bound     Marital_Status  \
# 9   No Urgent Place  ...               49999  Unmarried partner
# 13             Home  ...               49999  Unmarried partner
# 17             Work  ...               49999  Unmarried partner
#
#    Occupation_Type Passenger Restaurant20To50  RestaurantLessThan20  \
# 9       Unemployed    Kid(s)              1~3                   4~8
# 13      Unemployed     Alone              1~3                   4~8
# 17      Unemployed     Alone              1~3                   4~8
#
#    Temperature  Time  Weather time_24h
# 9           80  10AM    Sunny    10:00
# 13          55   6PM    Sunny    18:00
# 17          55   7AM    Sunny    07:00
#
# [3 rows x 28 columns]

# %%
coupon_counts = bar_coupons['Destination'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Destination')
plt.xlabel('Count')
plt.ylabel('Destination')
#plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Education_Level'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Education_Level')
plt.xlabel('Count')
plt.ylabel('Education_Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Has_Children'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Has_Children')
plt.xlabel('Count')
plt.ylabel('Has_Children')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Age'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
coupon_counts = bar_coupons['Time'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Time')
plt.xlabel('Count')
plt.ylabel('Time')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Marital_Status'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Marital_Status')
plt.xlabel('Count')
plt.ylabel('Marital_Status')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Passenger'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Passenger')
plt.xlabel('Count')
plt.ylabel('Passenger')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Gender'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Gender')
plt.xlabel('Count')
plt.ylabel('Gender')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
coupon_counts = bar_coupons['Age'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
coupon_counts.plot(kind='barh')

plt.title('Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter rows where Coupon_Type is 'Bar'
bar_coupons = df[df['Coupon_Type'] == 'Bar']

# Calculate the proportion where Coupon_Acceptance is 1
accepted_bar_coupons = bar_coupons[bar_coupons['Coupon_Acceptance'] == 1]
proportion = len(accepted_bar_coupons) / len(bar_coupons) if len(bar_coupons) > 0 else 0
proportion = round(proportion * 100, 2)
print(f"Proportion Accepted: {proportion_accepted}%")
# Out:
# Proportion Accepted: 56.76%

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
bar_coupons_valid = bar_coupons[bar_coupons['Coupon_Type'].notnull()]
bar_coupons_valid
# Out:
#       Age Bar_Frequency CarryAway CoffeeHouse  Coupon_Acceptance  \
# 9      21         never         0       never                  0
# 13     21         never         0       never                  1
# 17     21         never         0       never                  0
# 24     21         never       4~8       less1                  1
# 35     21         never       4~8       less1                  1
# ...    ..           ...       ...         ...                ...
# 12663  26         never       1~3       never                  0
# 12664  26         never       1~3       never                  0
# 12667  26         never       1~3       never                  0
# 12670  26         never       1~3       never                  0
# 12682  26         never       1~3       never                  0
#
#        Coupon_GEQ15min  Coupon_GEQ25min  Coupon_GEQ5min Coupon_Type  \
# 9                    1                0               1         Bar
# 13                   0                0               1         Bar
# 17                   1                1               1         Bar
# 24                   0                0               1         Bar
# 35                   0                0               1         Bar
# ...                ...              ...             ...         ...
# 12663                1                0               1         Bar
# 12664                1                0               1         Bar
# 12667                1                0               1         Bar
# 12670                1                0               1         Bar
# 12682                1                1               1         Bar
#
#            Destination  ...  Income upper bound     Marital_Status  \
# 9      No Urgent Place  ...               49999  Unmarried partner
# 13                Home  ...               49999  Unmarried partner
# 17                Work  ...               49999  Unmarried partner
# 24     No Urgent Place  ...               74999             Single
# 35                Home  ...               74999             Single
# ...                ...  ...                 ...                ...
# 12663  No Urgent Place  ...               87499             Single
# 12664  No Urgent Place  ...               87499             Single
# 12667  No Urgent Place  ...               87499             Single
# 12670  No Urgent Place  ...               87499             Single
# 12682             Work  ...               87499             Single
#
#                   Occupation_Type  Passenger Restaurant20To50  \
# 9                      Unemployed     Kid(s)              1~3
# 13                     Unemployed      Alone              1~3
# 17                     Unemployed      Alone              1~3
# 24     Architecture & Engineering  Friend(s)            less1
# 35     Architecture & Engineering      Alone            less1
# ...                           ...        ...              ...
# 12663             Sales & Related  Friend(s)              1~3
# 12664             Sales & Related  Friend(s)              1~3
# 12667             Sales & Related      Alone              1~3
# 12670             Sales & Related    Partner              1~3
# 12682             Sales & Related      Alone              1~3
#
#        RestaurantLessThan20 Temperature  Time  Weather time_24h
# 9                       4~8          80  10AM    Sunny    10:00
# 13                      4~8          55   6PM    Sunny    18:00
# 17                      4~8          55   7AM    Sunny    07:00
# 24                      4~8          80  10AM    Sunny    10:00
# 35                      4~8          55   6PM    Sunny    18:00
# ...                     ...         ...   ...      ...      ...
# 12663                   4~8          80  10PM    Sunny    22:00
# 12664                   4~8          55  10PM    Sunny    22:00
# 12667                   4~8          55  10AM    Rainy    10:00
# 12670                   4~8          55   6PM    Rainy    18:00
# 12682                   4~8          30   7AM    Snowy    07:00
#
# [2010 rows x 28 columns]

# %%
# Define groups: 3 or fewer times vs. more than 3 times per month
few_times = ['never', 'less1', '1~3']
more_times = ['4~8', 'gt8']

# Calculate acceptance rate for each group
accept_few = bar_coupons_valid[bar_coupons_valid['CarryAway'].isin(few_times)]['Coupon_Acceptance'].mean()
accept_more = bar_coupons_valid[bar_coupons_valid['CarryAway'].isin(more_times)]['Coupon_Acceptance'].mean()

accept_few, accept_more
proportion_lessthan_3 = round(accept_few * 100, 2)
print(f"The Proportion acceptance rate of those who visited the bar 3 or fewer: {proportion_lessthan_3}%")

proportion_morethan_3 = round(accept_more * 100, 2)
print(f"The Proportion acceptance rate of those who visited the bar more than 3: {proportion_morethan_3}%")
# Out:
# The Proportion acceptance rate of those who visited the bar 3 or fewer: 39.53%
# The Proportion acceptance rate of those who visited the bar more than 3: 42.01%

# %%
# Group customers based on Bar_Frequency
group_3_or_fewer = bar_coupons[bar_coupons['Bar_Frequency'].isin(['never', 'less1', '1~3'])]
group_more_than_3 = bar_coupons[bar_coupons['Bar_Frequency'].isin(['4~8', 'gt8'])]

# Calculate acceptance rates
acceptance_rate_3_or_fewer = group_3_or_fewer['Coupon_Acceptance'].mean()
proportion = round(acceptance_rate_3_or_fewer * 100, 2)
print(f"The Proportion acceptance rate of those who visited the bar 3 or fewer: {proportion}%")

acceptance_rate_more_than_3 = group_more_than_3['Coupon_Acceptance'].mean()
proportion2 = round(acceptance_rate_more_than_3 * 100, 2)
print(f"The Proportion acceptance rate of those who visited the bar 3 or fewer: {proportion2}%")

#(0.37061769616026713, 0.7688442211055276)
# Out:
# The Proportion acceptance rate of those who visited the bar 3 or fewer: 37.04%
# The Proportion acceptance rate of those who visited the bar 3 or fewer: 76.88%

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# Define conditions
bar_more_than_once = ['4~8', 'gt8', '1~3']  
over_25 = ['26', '31', '36', '41', '46', '50plus']

# Group 1:  this series represents drivers who go to a bar more than once a month and are over 25
group1 = bar_coupons[(bar_coupons['Bar_Frequency'].isin(bar_more_than_once)) & (bar_coupons['Age'].isin(over_25))]

# Group 2: this series represents isall others
group2 = bar_coupons[~((bar_coupons['Bar_Frequency'].isin(bar_more_than_once)) & (bar_coupons['Age'].isin(over_25)))]

# acceptance rates
accept_group1 = group1['Coupon_Acceptance'].mean()
accept_group1 = round(accept_group1 * 100, 2)
print(f"The comparison of Bar Coupon Acceptance Rates: of Group 1 Go to a bar more than once a month and are over: {accept_group1}%")

accept_group2 = group2['Coupon_Acceptance'].mean()
accept_group2 = round(accept_group2 * 100, 2)
print(f"The comparison of Bar Coupon Acceptance Rates of Group 2 All other drivers: {accept_group2}%")

accept_group1, accept_group2
# Out:
# The comparison of Bar Coupon Acceptance Rates: of Group 1 Go to a bar more than once a month and are over: 69.52%
# The comparison of Bar Coupon Acceptance Rates of Group 2 All other drivers: 33.46%
# (69.52, 33.46)

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
# Define conditions for the new comparison
bar_more_than_once = ['1~3', '4~8', 'gt8']
excluded_passengers = ['Alone', 'Friend(s)', 'Partner']  # not 'Kid(s)'
excluded_occupations = ['Farming, Fishing & Forestry']

# Group 1: go to bars > once/month, passengers not kids, occupation not in excluded list
group1 = bar_coupons[
    (bar_coupons['Bar_Frequency'].isin(bar_more_than_once)) &
    (bar_coupons['Passenger'].isin(excluded_passengers)) &
    (~bar_coupons['Occupation_Type'].isin(excluded_occupations))
]

# Group 2: all others
group2 = bar_coupons[~(
    (bar_coupons['Bar_Frequency'].isin(bar_more_than_once)) &
    (bar_coupons['Passenger'].isin(excluded_passengers)) &
    (~bar_coupons['Occupation_Type'].isin(excluded_occupations))
)]

# Calculate acceptance rates
accept_group1 = group1['Coupon_Acceptance'].mean()
accept_group2 = group2['Coupon_Acceptance'].mean()

accept_group1, accept_group2

accept_group1 = round(accept_group1 * 100, 2)
print(f"Group 1 who go to bars more than once a month, had no kids as passengers, and worked in occupations other than farming, fishing, or forestry is {accept_group1}%")

accept_group2 = round(accept_group2 * 100, 2)
print(f"Group 2 All other drivers: {accept_group2}%")
# Out:
# Group 1 who go to bars more than once a month, had no kids as passengers, and worked in occupations other than farming, fishing, or forestry is 71.32%
# Group 2 All other drivers: 29.54%

# %% [markdown]
# **6. Compare the acceptance rates between those drivers who:**
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed or
# - go to bars more than once a month and are under the age of 30 or
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %% [markdown]
# Group	Criteria	Acceptance Rate
# Group 1	Drivers who meet any of these:
# • Go to bars > once/month, no kids, not widowed
# • Go to bars > once/month and under 30
# • Go to cheap restaurants >4x/month and earn < $50K	56.9%
# Group 2	All other drivers	33.0%
#
# My Insight:
# About 57 out of 100 people in this group take the coupon. People who are more social, younger, or have
# less money are much more likely to take the bar coupon  almost twice as likely as everyone else and
# everyone else in this group 2, which is 33 out of 100 people are likly to say yes.

# %% [markdown]
# **7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?**

# %% [markdown]
# Key Observations
#
# Overall acceptance rate:
# About 41% of bar coupons were accepted — lower than the overall coupon acceptance rate (~57%).
#
# Behavioral patterns:
#
# Drivers who go to bars frequently (more than 3 times a month) were twice as likely to accept a bar coupon (≈77%) compared to infrequent bar-goers (≈37%).
#
# Those who go to bars more than once a month and are over 25 accepted coupons at a ~70% rate, versus ~33% for all others.
#
# Drivers who are social (not driving with kids) and work outside blue-collar jobs (like farming/fishing/forestry) accepted at ~71%, versus ~30% for others.
#
# When combining social behavior, age, and income factors, acceptance stayed high (57% vs 33% for others).
#
#  Hypothesis
#
# Drivers who accepted bar coupons are likely:
#
# Socially active adults — often traveling with friends or partners rather than kids.
#
# Frequent bar-goers who already associate going out with leisure and social activity.
#
# Middle-aged to younger adults (under 30–40) with moderate to lower income, who are more price-sensitive and responsive to discounts.
#
# Less likely to work in manual labor or rural professions, suggesting a more urban or socially engaged lifestyle.
#
#  Interpretation
#
# The data suggests bar coupon acceptance is driven more by lifestyle and social habits than by basic demographics like age alone.
# People who already engage in similar activities (frequenting bars, dining out, social trips) are primed to respond positively to such promotions.
#
#  Business Implication
#
# If you were advising a marketing or analytics team:
#
# Target promotions toward adults aged 25–40,
#
# Especially those who are social, urban, and cost-conscious,
#
# Use social settings (friends, partners) as part of the ad messaging to increase conversion.

# %% [markdown]
# **Executive Summary**
#
# *Analysis of the bar coupon dataset reveals that coupon acceptance is strongly influenced by
# lifestyle and social behavior rather than simple demographics. Drivers who frequent bars more
# than once a month, travel with friends or partners, and are between 25–40 years old show the
# highest acceptance rates often twice that of other groups. These individuals tend to be socially
# active, urban-based, and value cost-saving opportunities when engaging in leisure activities.
# Conversely, those with children as passengers or employed in rural or manual professions are less responsive.
# These insights suggest that bar coupon marketing campaigns should target socially engaged adults who already
# participate in nightlife and dining activities, leveraging their existing habits and price sensitivity to increase redemption rates.*

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
coffee_coupons = df[df['Coupon_Type'] == 'Coffee House']

# %%
coffee_coupons.head(2)
# Out:
#   Age Bar_Frequency CarryAway CoffeeHouse  Coupon_Acceptance  Coupon_GEQ15min  \
# 1  21         never         0       never                  0                0
# 3  21         never         0       never                  0                1
#
#    Coupon_GEQ25min  Coupon_GEQ5min   Coupon_Type      Destination  ...  \
# 1                0               1  Coffee House  No Urgent Place  ...
# 3                0               1  Coffee House  No Urgent Place  ...
#
#    Income upper bound     Marital_Status Occupation_Type  Passenger  \
# 1               49999  Unmarried partner      Unemployed  Friend(s)
# 3               49999  Unmarried partner      Unemployed  Friend(s)
#
#   Restaurant20To50  RestaurantLessThan20 Temperature  Time  Weather time_24h
# 1              1~3                   4~8          80  10AM    Sunny    10:00
# 3              1~3                   4~8          80   2PM    Sunny    14:00
#
# [2 rows x 28 columns]

# %%
accept_overall = coffee_coupons['Coupon_Acceptance'].mean()
#print(f"Overall acceptance rate: round{accept_overall}%, 2")

accept_overall = round(accept_overall * 100, 2)
print(f"The overall accept rate of coffee: {accept_overall}%")
# Out:
# The overall accept rate of coffee: 49.86%

# %%
coffee_accept_by_passenger = coffee_coupons.groupby('Passenger')['Coupon_Acceptance'].mean().sort_values(ascending=False)
print(coffee_accept_by_passenger)
# Out:
# Passenger
# Friend(s)    0.596248
# Partner      0.569079
# Kid(s)       0.480583
# Alone        0.437639
# Name: Coupon_Acceptance, dtype: float64

# %%
import matplotlib.pyplot as plt

coffee_accept_by_passenger.plot(kind='bar', figsize=(8,5), color='skyblue', edgecolor='black')
plt.title('Coffee House Coupon Acceptance by Passenger Type')
plt.ylabel('Acceptance Rate')
plt.xlabel('Passenger Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
coffee_accept_by_age = coffee_coupons.groupby('Age')['Coupon_Acceptance'].mean()
coffee_accept_by_age
# Out:
# Age
# 21         0.524349
# 26         0.514828
# 31         0.474194
# 36         0.467662
# 41         0.501538
# 46         0.509259
# 50plus     0.420183
# below21    0.696774
# Name: Coupon_Acceptance, dtype: float64

# %%
coffee_accept_by_income_upper = coffee_coupons.groupby('Income upper bound')['Coupon_Acceptance'].mean()
coffee_accept_by_income_upper
# Out:
# Income upper bound
# 0        0.513707
# 24999    0.540404
# 37499    0.473438
# 49999    0.542373
# 62499    0.503650
# 74999    0.436364
# 87499    0.296610
# 99999    0.554307
# Name: Coupon_Acceptance, dtype: float64

# %%
coffee_accept_by_income_lower = coffee_coupons.groupby('Income lower bound')['Coupon_Acceptance'].mean()
coffee_accept_by_income_lower
# Out:
# Income lower bound
# 0        0.513707
# 12500    0.540404
# 25000    0.473438
# 37500    0.542373
# 50000    0.503650
# 62500    0.436364
# 75000    0.296610
# 87500    0.554307
# Name: Coupon_Acceptance, dtype: float64

# %% [markdown]
# ***Passenger    	Behavior***
#
# *Friend(s):	Highest acceptance / coffee is a social activity.
# Partner:	    Moderate acceptance / likely to stop together.
# Alone:	    Lower acceptance / may not detour for coffee.
# Kid(s):	    Lowest acceptance / less likely to visit coffee shops with children.*

# %% [markdown]
# ***My Anslysis dictate the follow findings:***
#
# *Drivers who accept coffee house coupons tend to travel with friends or partners,
# are younger adults (21–35), and likely view coffee stops as social or leisure
# activities. Solo drivers and those with children as passengers are less inclined
# to accept, indicating that coupon acceptance is driven more by social context
# and convenience than necessity.*
